# %% [markdown]
# # Problem 5: The Penguins Dataset
#
# In this problem, we will use the **Palmer Penguins dataset** to explore descriptive statistics, visualisations, and relationships between variables.
#
# We will use Python libraries **pandas**, **numpy**, and **matplotlib** to perform the analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - **pandas**: For data manipulation and analysis, including reading CSV files and working with DataFrames.
# - **numpy**: For numerical operations, calculations, and working with arrays.
# - **matplotlib.pyplot**: For creating visualizations such as line plots, histograms, and scatter plots.

# %%
# Load the Palmer Penguins dataset 
url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"
penguins = pd.read_csv(url)
# Display the first 5 rows to check it loaded correctly
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
variable = 'body_mass_g' # Define a variable name (as a string) that matches a column in the dataset
# This will be used to select the 'body_mass_g' column from the penguins DataFrame

# %%
# Descriptive statistics for numeric columns
penguins.describe()
# describe() gives you mean, std, min, max, quartiles for all numeric columns like:
# bill_length_mm
# bill_depth_mm
# flipper_length_mm
# body_mass_g
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# From the descriptive statistics, we can see the central tendency (mean), spread (std), and range (min, max) of the penguin measurements. Quartiles help understand the distribution and identify potential outliers.

# %%
# Select numeric variable
# Select numeric variable
plt.figure(figsize=(8,5)# Create a new figure with specific width and height
plt.hist(penguins[])
